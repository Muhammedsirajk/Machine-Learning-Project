# %% [markdown]
# ### <center> DAIMOND PRICE PREDICTION

# %% [markdown]
# ![daimond-2.webp](attachment:daimond-2.webp)

# %% [markdown]
#    ### ABOUT
# ####  These dataset contain 10 features in which 'Price(in US dollars)' is dependent feature. The goal is we have to predict the price of Diamond using different Regression Algorithms

# %% [markdown]
# #### importing libraries

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import klib as k
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import Lasso,LinearRegression,LogisticRegression,Ridge
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import LinearSVR
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv("cubic_zirconia.csv")
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table     x     y  \
# 0               1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29
# 1               2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46
# 2               3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12
# 3               4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80
# 4               5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43
# ...           ...    ...        ...   ...     ...    ...    ...   ...   ...
# 26962       26963   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52
# 26963       26964   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42
# 26964       26965   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15
# 26965       26966   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20
# 26966       26967   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88
#
#           z  price
# 0      2.66    499
# 1      2.70    984
# 2      3.78   6289
# 3      2.96   1082
# 4      2.65    779
# ...     ...    ...
# 26962  4.09   5408
# 26963  2.74   1114
# 26964  3.17   1656
# 26965  2.60    682
# 26966  4.27   5166
#
# [26967 rows x 11 columns]

# %% [markdown]
# ###  EDA

# %%
df['cut'] = df['cut'].str.replace('^b','')

# %%
df['clarity'] = df['clarity'].str.replace('^b','')
df['color'] = df['color'].str.replace('^b','')

# %%
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table     x     y  \
# 0               1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29
# 1               2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46
# 2               3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12
# 3               4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80
# 4               5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43
# ...           ...    ...        ...   ...     ...    ...    ...   ...   ...
# 26962       26963   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52
# 26963       26964   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42
# 26964       26965   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15
# 26965       26966   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20
# 26966       26967   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88
#
#           z  price
# 0      2.66    499
# 1      2.70    984
# 2      3.78   6289
# 3      2.96   1082
# 4      2.65    779
# ...     ...    ...
# 26962  4.09   5408
# 26963  2.74   1114
# 26964  3.17   1656
# 26965  2.60    682
# 26966  4.27   5166
#
# [26967 rows x 11 columns]

# %%
df.shape
# Out:
# (22231, 10)

# %%
df.isnull().mean()*100
# Out:
# carat      0.0
# cut        0.0
# color      0.0
# clarity    0.0
# depth      0.0
# table      0.0
# x          0.0
# y          0.0
# z          0.0
# price      0.0
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 21

# %%
df.drop_duplicates()
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z   price
# 0       0.30  1.0    1.0      2.0   62.1   58.0  4.27  4.29  2.66   499.0
# 1       0.33  2.0    3.0      1.0   60.8   58.0  4.42  4.46  2.70   984.0
# 2       0.90  3.0    1.0      7.0   62.2   60.0  6.04  6.12  3.78  6289.0
# 3       0.42  1.0    2.0      4.0   61.6   56.0  4.82  4.80  2.96  1082.0
# 4       0.31  1.0    2.0      6.0   60.4   59.0  4.35  4.43  2.65   779.0
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...     ...
# 26962   1.11  2.0    3.0      2.0   62.3   58.0  6.61  6.52  4.09  5408.0
# 26963   0.33  1.0    4.0      1.0   61.9   55.0  4.44  4.42  2.74  1114.0
# 26964   0.51  2.0    1.0      5.0   61.7   58.0  5.12  5.15  3.17  1656.0
# 26965   0.27  3.0    2.0      7.0   61.8   56.0  4.19  4.20  2.60   682.0
# 26966   1.25  2.0    6.0      2.0   62.0   58.0  6.90  6.88  4.27  5166.0
#
# [22210 rows x 10 columns]

# %%
df.describe().T
# Out:
#            count         mean          std     min     25%      50%      75%  \
# carat    22231.0     0.685494     0.354168    0.20    0.36     0.57     1.01
# cut      22231.0     1.636409     0.923626    0.00    1.00     1.00     2.00
# color    22231.0     2.534704     1.686908    0.00    1.00     3.00     4.00
# clarity  22231.0     3.879987     1.730021    0.00    2.00     4.00     5.00
# depth    22231.0    61.790464     1.057561   59.00   61.20    61.90    62.50
# table    22231.0    57.222478     2.003545   52.00   56.00    57.00    59.00
# x        22231.0     5.490826     0.952983    3.73    4.59     5.34     6.37
# y        22231.0     5.496146     0.947063    3.71    4.60     5.35     6.37
# z        22231.0     3.394394     0.590284    1.53    2.83     3.29     3.95
# price    22231.0  2879.654222  2461.760499  326.00  871.00  1919.00  4413.50
#
#               max
# carat        1.95
# cut          3.00
# color        6.00
# clarity      7.00
# depth       64.60
# table       63.30
# x            8.10
# y            8.05
# z            5.06
# price    10309.00

# %% [markdown]
# #### DATA VISUALIZATION

# %%
cut_price = df.groupby(['cut'])['price'].sum()
cut_price.plot.pie(title='Pie plot of cut vs price',
                   autopct='%1.1f%%', startangle=90,explode=[0, 0.1, 0, 0],legend=True);

# %%
clarity_price = df.groupby(['clarity'])['price'].sum()
clarity_price.plot.pie(title='Pie plot of clarity vs price',
                   autopct='%1.1f%%', startangle=90,legend=True,figsize=(5,5));

# %%
cut_price = df.groupby(['color'])['price'].sum()
cut_price.plot.pie(title='Pie plot of color vs price',
                   autopct='%1.1f%%', startangle=90,legend=True,explode=[0, 0, 0, 0.1,0,0,0],figsize=(5,5));

# %%
k.dist_plot(df);
# Out:
# Large dataset detected, using 10000 random samples for the plots. Summary statistics are still based on the entire dataset.

# %%
df.cut.unique()
# Out:
# array([2., 3., 4., 1.])

# %% [markdown]
# ### changing catagorical data to numerical

# %%
le=LabelEncoder()

# %%
df["cut"]=le.fit_transform(df.cut)

# %%
df["color"]=le.fit_transform(df.color)
df["clarity"]=le.fit_transform(df.clarity)

# %%
df
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z   price
# 0       0.30    1      1        2   62.1   58.0  4.27  4.29  2.66   499.0
# 1       0.33    2      3        1   60.8   58.0  4.42  4.46  2.70   984.0
# 2       0.90    3      1        7   62.2   60.0  6.04  6.12  3.78  6289.0
# 3       0.42    1      2        4   61.6   56.0  4.82  4.80  2.96  1082.0
# 4       0.31    1      2        6   60.4   59.0  4.35  4.43  2.65   779.0
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...     ...
# 26962   1.11    2      3        2   62.3   58.0  6.61  6.52  4.09  5408.0
# 26963   0.33    1      4        1   61.9   55.0  4.44  4.42  2.74  1114.0
# 26964   0.51    2      1        5   61.7   58.0  5.12  5.15  3.17  1656.0
# 26965   0.27    3      2        7   61.8   56.0  4.19  4.20  2.60   682.0
# 26966   1.25    2      6        2   62.0   58.0  6.90  6.88  4.27  5166.0
#
# [23022 rows x 10 columns]

# %% [markdown]
# ### KDA PLOT

# %%
for i in df.columns:
    if df[i].dtype != "object":
        sns.kdeplot(x=df[i],color="GREEN")
        plt.show();

# %% [markdown]
#   ### HISTOGRAM

# %%
for i in df.columns:
    if df[i].dtype != "object":
        sns.histplot(x=df[i],color="GREEN")
        plt.show();

# %% [markdown]
# ### HEATMAP

# %%
k.corr_plot(data=df,target="price");

# %%
k.clean_column_names(df)
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z   price
# 0       0.30    1      1        2   62.1   58.0  4.27  4.29  2.66   499.0
# 1       0.33    2      3        1   60.8   58.0  4.42  4.46  2.70   984.0
# 2       0.90    3      1        7   62.2   60.0  6.04  6.12  3.78  6289.0
# 3       0.42    1      2        4   61.6   56.0  4.82  4.80  2.96  1082.0
# 4       0.31    1      2        6   60.4   59.0  4.35  4.43  2.65   779.0
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...     ...
# 26962   1.11    2      3        2   62.3   58.0  6.61  6.52  4.09  5408.0
# 26963   0.33    1      4        1   61.9   55.0  4.44  4.42  2.74  1114.0
# 26964   0.51    2      1        5   61.7   58.0  5.12  5.15  3.17  1656.0
# 26965   0.27    3      2        7   61.8   56.0  4.19  4.20  2.60   682.0
# 26966   1.25    2      6        2   62.0   58.0  6.90  6.88  4.27  5166.0
#
# [23022 rows x 10 columns]

# %% [markdown]
# ### boxplot

# %%
for i in df.columns:
    if df[i].dtype!="object":
            sns.boxplot(y=df[i],color="red")
            plt.show()

# %% [markdown]
# ### cleaning the outliers

# %%
def outlier(col):
    Q3, Q1= np.nanpercentile(col,[75,25])
    iqr=Q3-Q1
    ul=Q3+1.5*iqr
    ll=Q1-1.5*iqr
    return ul, ll

# %%
for column in df.columns:
    if df[column].dtype !="object":
        ul,ll=outlier(df[column])
        df[column]=np.where((df[column]>ul)|(df[column]<ll),np.nan,df[column])

# %%
for i in df.columns:
    if df[i].dtype !="object":
        sns.boxplot(y=df[i],color="green")
        plt.show()

# %%
df.dropna(inplace=True)

# %% [markdown]
# ### REGRESSION

# %%
df
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z   price
# 0       0.30  1.0    1.0      2.0   62.1   58.0  4.27  4.29  2.66   499.0
# 1       0.33  2.0    3.0      1.0   60.8   58.0  4.42  4.46  2.70   984.0
# 2       0.90  3.0    1.0      7.0   62.2   60.0  6.04  6.12  3.78  6289.0
# 3       0.42  1.0    2.0      4.0   61.6   56.0  4.82  4.80  2.96  1082.0
# 4       0.31  1.0    2.0      6.0   60.4   59.0  4.35  4.43  2.65   779.0
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...     ...
# 26962   1.11  2.0    3.0      2.0   62.3   58.0  6.61  6.52  4.09  5408.0
# 26963   0.33  1.0    4.0      1.0   61.9   55.0  4.44  4.42  2.74  1114.0
# 26964   0.51  2.0    1.0      5.0   61.7   58.0  5.12  5.15  3.17  1656.0
# 26965   0.27  3.0    2.0      7.0   61.8   56.0  4.19  4.20  2.60   682.0
# 26966   1.25  2.0    6.0      2.0   62.0   58.0  6.90  6.88  4.27  5166.0
#
# [22231 rows x 10 columns]

# %%
x=df[["carat","cut","color","depth","table","x","y","z"]].values

# %%
y=df[["price"]].values

# %%
sc=StandardScaler()

# %%
x=sc.fit_transform(x)

# %% [markdown]
# ### CROSS VALIDATION

# %%
models = {
    "LinearRegression": LinearRegression(),
    "Lasso":Lasso(),
    "Ridge":Ridge(),
    "DecisionTreeRegressor":DecisionTreeRegressor(),
    "RandomForestRegressor":RandomForestRegressor()
}

# %%
for name, model in models.items():
    scores = cross_val_score(model, x,y, scoring="neg_mean_squared_error",cv=10,n_jobs=-1)
    print("cross validation model : {}".format(name))
    rmse = np.sqrt(-scores)
    rmse_average = np.mean(rmse)
    print("AVERAGE RMSE: ",rmse_average)
    print("*"*100)
# Out:
# cross validation model : LinearRegression
# AVERAGE RMSE:  864.9186831167124
# ****************************************************************************************************
# cross validation model : Lasso
# AVERAGE RMSE:  865.5950061186438
# ****************************************************************************************************
# cross validation model : Ridge
# AVERAGE RMSE:  864.9066886770981
# ****************************************************************************************************
# cross validation model : DecisionTreeRegressor
# AVERAGE RMSE:  1039.2418900535272
# ****************************************************************************************************
# cross validation model : RandomForestRegressor
# AVERAGE RMSE:  756.0575749006267
# ****************************************************************************************************

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
models={
    "linearregression":LinearRegression(),
    "ridge":Ridge(),
    "lasso":Lasso(),
    "decisiontreeregressor":DecisionTreeRegressor(),
    "randomforestregressor":RandomForestRegressor(random_state=0)
}

# %%
for name,model in models.items():
    model.fit(x_train,y_train)
    print("model trained with{}".format(name))
    training_score =model.score(x_train,y_train)*100
    testing_score =model.score(x_test,y_test)*100
    score =r2_score(y_test,model.predict(x_test))*100
    mae = mean_absolute_error(y_test, model.predict(x_test))
    mse= mean_squared_error(y_test,model.predict(x_test))
    rmse= np.sqrt(mse)
    print("r2score: ",score)
    print("training_score:",training_score)
    print("testing_score:",testing_score)
    print("mae:",mae)
    print("mse:",mse)
    print("rmse_test:",rmse)
    print("   "*105)
# Out:
# model trained withlinearregression
# r2score:  87.73928343474654
# training_score: 87.64481287280985
# testing_score: 87.73928343474654
# mae: 545.5788715099972
# mse: 726574.3676831346
# rmse_test: 852.3933174791639
#
# model trained withridge
# r2score:  87.74219248707631
# training_score: 87.64464654632611
# testing_score: 87.74219248707631
# mae: 545.5605700637451
# mse: 726401.976220873
# rmse_test: 852.2921894637267
#
# model trained withlasso
# r2score:  87.74691834677107
# training_score: 87.6197722581689
# testing_score: 87.74691834677107
# mae: 544.7070294043598
# mse: 726121.9201163859
# rmse_test: 852.1278777955723
#
# model trained withdecisiontreeregressor
# r2score:  82.38281062665963
# training_score: 99.99208746716866
# testing_score: 82.38281062665963
# mae: 584.3874522149764
# mse: 1044000.8266371835
# rmse_test: 1021.763586470561
#
# model trained withrandomforestregressor
# r2score:  90.1466868216587
# training_score: 98.69272471126581
# testing_score: 90.1466868216587
# mae: 446.7991206144129
# mse: 583910.7978750692
# rmse_test: 764.1405615952272

# %% [markdown]
# ### model training

# %%
model=RandomForestRegressor()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
#  ### PRICE PREDICTION

# %%
y_pred = model.predict(x)

# %%
op=pd.DataFrame(zip(y,y_pred),columns=("ACTUAL","PREDICTED"),dtype=float)

# %% [markdown]
# ### scatterplot

# %%
plt.figure(figsize=(10,6))
plt.xticks()
sns.scatterplot(data=op,x='ACTUAL',y="PREDICTED")
plt.show();

# %% [markdown]
# ### LINE PLOT

# %%
plt.figure(figsize=(10,6))
plt.xticks()
sns.lineplot(data=op,x='ACTUAL',y="PREDICTED")
plt.show();

# %% [markdown]
# ### CONCLUTION
